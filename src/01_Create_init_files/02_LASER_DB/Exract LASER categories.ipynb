# %%
import os

if not os.path.exists("LASER_product_ontology.txt"):
    # !wget -O LASER_product_ontology.txt "https://bitbucket.org/jdwinkler/laser_release/raw/f6ce080a8993ee259c4914ce92f83b1f966bab2d/inputs/Product%20Ontology.txt"
# Out:
# --2024-08-23 20:27:31--  https://bitbucket.org/jdwinkler/laser_release/raw/f6ce080a8993ee259c4914ce92f83b1f966bab2d/inputs/Product%20Ontology.txt
# Resolviendo bitbucket.org (bitbucket.org)... 2401:1d80:3210:2:0:bbc:1:df7c, 2401:1d80:3210::bbc:1:df7c, 2401:1d80:3210:1:0:bbc:1:df7c, ...
# Conectando con bitbucket.org (bitbucket.org)[2401:1d80:3210:2:0:bbc:1:df7c]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 8968 (8.8K) [text/plain]
# Grabando a: «LASER_product_ontology.txt»
#
# LASER_product_ontol 100%[===================>]   8.76K  --.-KB/s    en 0s
#
# 2024-08-23 20:27:31 (4.18 GB/s) - «LASER_product_ontology.txt» guardado [8968/8968]

# %%
import pandas as pd

# %%
LASER_ontology = pd.read_csv('LASER_product_ontology.txt', sep='\t')

# %%
LASER_ontology.head()
# Out:
#             Product   Intended usage product class
# 0   (2S)-NARINGENIN  pharmaceuticals      chalcone
# 1  (2S)-PINOCEMBRIN   food additives     phenolics
# 2   1_2-PROPANEDIOL         polymers         diols
# 3   1_3-PROPANEDIOL         polymers         diols
# 4    1_4-BUTANEDIOL         polymers         diols
